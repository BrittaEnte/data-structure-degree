# %% [markdown]
# copy and deep coopy
# ![image.png](attachment:image.png)

# %%
new_list[0]=["a", "b", "c"]
# hier würde old list und new list unterschiedlich sein. 
# also muss man ggf. nicht shallow copy sondern deep copy nehmen.

# %% [markdown]
# ![image.png](attachment:image.png)
